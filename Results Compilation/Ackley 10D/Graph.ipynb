# %%
from matplotlib import rcParams
import numpy as np
import pandas as pd
import sys
from scipy.stats import mannwhitneyu
from collections import OrderedDict
rcParams["legend.numpoints"] = 1
import matplotlib.pyplot as plt
from matplotlib.transforms import offset_copy

linestyles = OrderedDict(
    [('solid',               (0, ())),
     ('loosely dotted',      (0, (1, 10))),
     ('dotted',              (0, (1, 5))),
     ('densely dotted',      (0, (1, 1))),

     ('loosely dashed',      (0, (5, 10))),
     ('dashed',              (0, (5, 5))),
     ('densely dashed',      (0, (5, 1))),

     ('loosely dashdotted',  (0, (3, 10, 1, 10))),
     ('dashdotted',          (0, (3, 5, 1, 5))),
     ('densely dashdotted',  (0, (3, 1, 1, 1))),

     ('loosely dashdotdotted', (0, (3, 10, 1, 10, 1, 10))),
     ('dashdotdotted',         (0, (3, 5, 1, 5, 1, 5))),
     ('densely dashdotdotted', (0, (3, 1, 1, 1, 1, 1)))])

Style = []
for i, (name, linestyle) in enumerate(linestyles.items()):
    Style.append(linestyle)
X = [50,100,150,200,250,300,350,400,450,500]

# %%
Minimax_1 = pd.read_csv('Minimax_1.csv').iloc[:,1:]
Minimax_2 = pd.read_csv('Minimax_2.csv').iloc[:,1:]
Minimax_3 = pd.read_csv('Minimax_2.csv').iloc[:,1:]
Composite_1 = pd.read_csv('Composite_1.csv').iloc[:,1:]
Composite_2 = pd.read_csv('Composite_2.csv').iloc[:,1:]
Composite_3 = pd.read_csv('Composite_3.csv').iloc[:,1:]

# %%
cols = ['Noise Level : 5 %','Noise Level : 10 %','Noise Level : 20 %']
rows = ['Robust Regularization','Robust Composition']

f, axarr = plt.subplots(2, 3,figsize=(20,11))


line = []
line.append(axarr[0,0].errorbar(X,Minimax_1['RMAE_Kriging'],marker='d',yerr=(np.array(Minimax_1['Std_Kriging'])),
                     color='r',label='Kriging',fillstyle='none',markersize=10)[0])
line.append(axarr[0,0].errorbar(X,Minimax_1['RMAE_KNN'],marker='p',yerr=(np.array(Minimax_1['Std_KNN'])),
                     color='b',label='KNN',fillstyle='none',markersize=10)[0])
line.append(axarr[0,0].errorbar(X,Minimax_1['RMAE_SVR'],marker='s',yerr=(np.array(Minimax_1['Std_SVR'])),
                     color='g',label='SVM',fillstyle='none',markersize=10)[0])
line.append(axarr[0,0].errorbar(X,Minimax_1['RMAE_RF'],marker='P',yerr=(np.array(Minimax_1['Std_RF'])),
                     color='k',label='RF',fillstyle='none',markersize=10)[0])
line.append(axarr[0,0].errorbar(X,Minimax_1['RMAE_ELN'],marker='X',yerr=(np.array(Minimax_1['Std_ELN'])),
                     color='darkred',label='ELN',fillstyle='none',markersize=10)[0])
line.append(axarr[0,0].errorbar(X,Minimax_1['RMAE_RBFN'],marker=11,yerr=(np.array(Minimax_1['Std_RBFN'])),
                     color='m',label='RBF',fillstyle='none',markersize=10)[0])




#ax1.set_xlabel('Sample Size')
#ax1.set_xlim(5,105)
axarr[0,0].set_yscale('log',basey=10)
#axarr[0,0].set_ylim(1e0,1e1)
axarr[0,0].set_ylabel('% RMAE',size=20)
#ax1.set_title('  Noise Level 1 : Robust Regularization ')
axarr[0,0].grid(which='major')

axarr[0,0].tick_params(labelsize=15)

axarr[0,1].errorbar(X,Minimax_2['RMAE_Kriging'],marker='d',yerr=(np.array(Minimax_2['Std_Kriging'])),color='r',fillstyle='none',markersize=10)
axarr[0,1].errorbar(X,Minimax_2['RMAE_KNN'],marker='p',yerr=(np.array(Minimax_2['Std_KNN'])),color='b',fillstyle='none',markersize=10)
axarr[0,1].errorbar(X,Minimax_2['RMAE_SVR'],marker='s',yerr=(np.array(Minimax_2['Std_SVR'])),color='g',fillstyle='none',markersize=10)
axarr[0,1].errorbar(X,Minimax_2['RMAE_RF'],marker='P',yerr=(np.array(Minimax_2['Std_RF'])),color='k',fillstyle='none',markersize=10)
axarr[0,1].errorbar(X,Minimax_2['RMAE_ELN'],marker='X',yerr=(np.array(Minimax_2['Std_ELN'])),color='darkred',fillstyle='none',markersize=10)
axarr[0,1].errorbar(X,Minimax_2['RMAE_RBFN'],marker=11,yerr=(np.array(Minimax_2['Std_RBFN'])),color='m',fillstyle='none',markersize=10)
#axarr[0,1].set_xlabel('Sample Size')

#axarr[0,1].set_ylim(1e0,1e1)
axarr[0,1].set_yscale('log',basey=10)
#ax2.set_ylabel('% RMAE')
#ax2.set_title(' Noise Level 2 : Robust Regularization ')
axarr[0,1].grid(which='major')

axarr[0,1].tick_params(labelsize=15)


axarr[0,2].errorbar(X,Minimax_3['RMAE_Kriging'],marker='d',yerr=(np.array(Minimax_3['Std_Kriging'])),color='r',fillstyle='none',markersize=10)
axarr[0,2].errorbar(X,Minimax_3['RMAE_KNN'],marker='p',yerr=(np.array(Minimax_3['Std_KNN'])),color='b',fillstyle='none',markersize=10)
axarr[0,2].errorbar(X,Minimax_3['RMAE_SVR'],marker='s',yerr=(np.array(Minimax_3['Std_SVR'])),color='g',fillstyle='none',markersize=10)
axarr[0,2].errorbar(X,Minimax_3['RMAE_RF'],marker='P',yerr=(np.array(Minimax_3['Std_RF'])),color='k',fillstyle='none',markersize=10)
axarr[0,2].errorbar(X,Minimax_3['RMAE_ELN'],marker='X',yerr=(np.array(Minimax_3['Std_ELN'])),color='darkred',fillstyle='none',markersize=10)
axarr[0,2].errorbar(X,Minimax_3['RMAE_RBFN'],marker=11,yerr=(np.array(Minimax_3['Std_RBFN'])),color='m',fillstyle='none',markersize=10)
#axarr[0,2].set_xlabel('Sample Size')

#axarr[0,2].set_ylim(1e0,1e1)
axarr[0,2].set_yscale('log',basey=10)
#axarr[0,2].set_ylabel('% RMAE')
#axarr[0,2].set_title('Noise Level 3 : Robust Regularization ')
axarr[0,2].grid(which='major')

axarr[0,2].tick_params(labelsize=15)

axarr[1,0].errorbar(X,Composite_1['RMAE_Kriging'],marker='d',yerr=(np.array(Composite_1['Std_Kriging'])),color='r',fillstyle='none',markersize=10)
axarr[1,0].errorbar(X,Composite_1['RMAE_KNN'],marker='p',yerr=(np.array(Composite_1['Std_KNN'])),color='b',fillstyle='none',markersize=10)
axarr[1,0].errorbar(X,Composite_1['RMAE_SVR'],marker='s',yerr=(np.array(Composite_1['Std_SVR'])),color='g',fillstyle='none',markersize=10)
axarr[1,0].errorbar(X,Composite_1['RMAE_RF'],marker='P',yerr=(np.array(Composite_1['Std_RF'])),color='k',fillstyle='none',markersize=10)
axarr[1,0].errorbar(X,Composite_1['RMAE_ELN'],marker='X',yerr=(np.array(Composite_1['Std_ELN'])),color='darkred',fillstyle='none',markersize=10)
axarr[1,0].errorbar(X,Composite_1['RMAE_RBFN'],marker=11,yerr=(np.array(Composite_1['Std_RBFN'])),color='m',fillstyle='none',markersize=10)
axarr[1,0].set_xlabel('Sample Size - DoE (LHC)',size=20)

axarr[1,0].set_yscale('log',basey=10)
axarr[1,0].set_ylabel('% RMAE',size=20)
#ax4.set_title(' Noise Level 1 : Robust Composition ')
axarr[1,0].grid(which='major')

axarr[1,0].tick_params(labelsize=15)

axarr[1,1].errorbar(X,Composite_2['RMAE_Kriging'],marker='d',yerr=(np.array(Composite_2['Std_Kriging'])),color='r',fillstyle='none',markersize=10)
axarr[1,1].errorbar(X,Composite_2['RMAE_KNN'],marker='p',yerr=(np.array(Composite_2['Std_KNN'])),color='b',fillstyle='none',markersize=10)
axarr[1,1].errorbar(X,Composite_2['RMAE_SVR'],marker='s',yerr=(np.array(Composite_2['Std_SVR'])),color='g',fillstyle='none',markersize=10)
axarr[1,1].errorbar(X,Composite_2['RMAE_RF'],marker='P',yerr=(np.array(Composite_2['Std_RF'])),color='k',fillstyle='none',markersize=10)
axarr[1,1].errorbar(X,Composite_2['RMAE_ELN'],marker='X',yerr=(np.array(Composite_2['Std_ELN'])),color='darkred',fillstyle='none',markersize=10)
axarr[1,1].errorbar(X,Composite_2['RMAE_RBFN'],marker=11,yerr=(np.array(Composite_2['Std_RBFN'])),color='m',fillstyle='none',markersize=10)
axarr[1,1].set_xlabel('Sample Size - DoE (LHC)',size=20)

axarr[1,1].set_yscale('log',basey=10)
#axarr[1,1].set_ylabel('% RMAE')
#ax5.set_title('Noise Level 2 : Robust Composition ')
axarr[1,1].grid(which='major')

axarr[1,1].tick_params(labelsize=15)

axarr[1,2].errorbar(X,Composite_3['RMAE_Kriging'],marker='d',yerr=(np.array(Composite_3['Std_Kriging'])),color='r',fillstyle='none',markersize=10)
axarr[1,2].errorbar(X,Composite_3['RMAE_KNN'],marker='p',yerr=(np.array(Composite_3['Std_KNN'])),color='b',fillstyle='none',markersize=10)
axarr[1,2].errorbar(X,Composite_3['RMAE_SVR'],marker='s',yerr=(np.array(Composite_3['Std_SVR'])),color='g',fillstyle='none',markersize=10)
axarr[1,2].errorbar(X,Composite_3['RMAE_RF'],marker='P',yerr=(np.array(Composite_3['Std_RF'])),color='k',fillstyle='none',markersize=10)
axarr[1,2].errorbar(X,Composite_3['RMAE_ELN'],marker='X',yerr=(np.array(Composite_3['Std_ELN'])),color='darkred',fillstyle='none',markersize=10)
axarr[1,2].errorbar(X,Composite_3['RMAE_RBFN'],marker=11,yerr=(np.array(Composite_3['Std_RBFN'])),color='m',fillstyle='none',markersize=10)
axarr[1,2].set_xlabel('Sample Size - DoE (LHC)',size=20)

axarr[1,2].set_yscale('log',basey=10)
#ax6.set_ylabel('% RMAE')
#ax6.set_title('Noise Level 3 : Robust Composition ')
axarr[1,2].grid(which='major')
#axarr[1,2].tight_layout()

axarr[1,2].tick_params(labelsize=15)

pad = 10

for ax, col in zip(axarr[0], cols):
    ax.annotate(col, xy=(0.5, 1.02), xytext=(0, pad),
                xycoords='axes fraction', textcoords='offset points',
                size=20, ha='center', va='baseline')
    

for ax, row in zip(axarr[:,0], rows):
    ax.annotate(row, xy=(0, 0.9), xytext=(-ax.yaxis.labelpad - pad, 0),
                xycoords=ax.yaxis.label, textcoords='offset points',
                size=20, ha='right', va='center' , rotation = 90)
    



f.tight_layout()   



f.legend(line, ['Kriging', 'KNN', 'SVM', 'RF', 'ELN', 'RBF'], loc='upper left', fontsize=24 , 
         ncol=6 , bbox_to_anchor=(0.2, 1.1),fancybox=True  )

    
plt.show()
f.savefig("Ackley10D.jpg",bbox_inches='tight')

# %%
np.mean(Minimax_1)[:6]
# Out:
# RMAE_Kriging    1.304755
# RMAE_SVR        1.097598
# RMAE_RBFN       1.449891
# RMAE_KNN        1.525947
# RMAE_ELN        1.126141
# RMAE_RF         1.410585
# dtype: float64

# %%
np.mean(Minimax_2)[:6]
# Out:
# RMAE_Kriging    1.369843
# RMAE_SVR        1.141275
# RMAE_RBFN       1.569287
# RMAE_KNN        1.478527
# RMAE_ELN        1.219815
# RMAE_RF         1.369193
# dtype: float64

# %%
np.mean(Minimax_3)[:6]
# Out:
# RMAE_Kriging    1.369843
# RMAE_SVR        1.141275
# RMAE_RBFN       1.569287
# RMAE_KNN        1.478527
# RMAE_ELN        1.219815
# RMAE_RF         1.369193
# dtype: float64

# %%
np.mean(Composite_1)[:6]
# Out:
# RMAE_Kriging    0.807567
# RMAE_SVR        0.705963
# RMAE_RBFN       1.128262
# RMAE_KNN        1.284249
# RMAE_ELN        0.643858
# RMAE_RF         1.102783
# dtype: float64

# %%
np.mean(Composite_2)[:6]
# Out:
# RMAE_Kriging    0.785452
# RMAE_SVR        0.693602
# RMAE_RBFN       1.147029
# RMAE_KNN        1.257298
# RMAE_ELN        0.626187
# RMAE_RF         1.077223
# dtype: float64

# %%
np.mean(Composite_3)[:6]
# Out:
# RMAE_Kriging    0.728280
# RMAE_SVR        0.662687
# RMAE_RBFN       1.077392
# RMAE_KNN        1.180667
# RMAE_ELN        0.579128
# RMAE_RF         1.006646
# dtype: float64

# %%
1st : Kriging : 0 , SVM : 3 , RBFN : 0 , KNN : 0 , RF : 0 , ELN : 3,
# Out:
#   File "<ipython-input-10-44c89ff30be0>", line 1
#     1st : Kriging : 0 , SVM : 3 , RBFN : 0 , KNN : 0 , RF : 0 , ELN : 3,
#       ^
# SyntaxError: invalid syntax

# %%
2nd : Kriging : 0 , SVM : 3 , RBFN : 0 , KNN : 0, RF : 0, ELN : 3 ,

# %%
3rd : Kriging : 4 , SVM : 0 , RBFN : 0 , KNN : 0 , RF : 2 , ELN : 0,
